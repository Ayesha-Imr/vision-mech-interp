# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Imr/vision-mech-interp/blob/main/Segment_2_canonical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q torch-lucent
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 113.0 MB/s eta 0:00:00
#   Building wheel for docopt (setup.py) ... done

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
from lucent.optvis import render, param
from lucent.modelzoo import inceptionv1
from PIL import Image

# %%
# Save all files to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

def load_model(device):
    model = inceptionv1(pretrained=True)
    model.to(device)
    model.eval()

    for p in model.parameters():
        p.requires_grad = False

    return model


model = load_model(DEVICE)

def activation_maximization(
    model,
    layer_name,
    neuron_id,
    image_size=512,
    num_steps=1024,
):


    objective = f"{layer_name}:{neuron_id}"

    param_f = lambda: param.image(
        image_size,
        fft=True,
        decorrelate=True,
    )

    images = render.render_vis(
        model,
        objective,
        param_f=param_f,
        thresholds=(num_steps,),
        show_image=False,
        verbose=False,
    )

    return images[0][0]
# Out:
# Using device: cuda
# Downloading: "https://github.com/ProGamerGov/pytorch-old-tensorflow-models/raw/master/inception5h.pth" to /root/.cache/torch/hub/checkpoints/inception5h.pth
# 100%|██████████| 27.0M/27.0M [00:00<00:00, 765MB/s]

# %%
#Configuration
LAYER = "mixed3b" #Enter the layer you want to work on
NEURONS = range(0,480) #Enter the neuron/unit range for visualizing their activation maximizations

DRIVE_PATH = "/content/drive/MyDrive/activation_max_results"

save_dir = os.path.join(DRIVE_PATH, LAYER)
os.makedirs(save_dir, exist_ok=True)

# Generate and Save Images
for id in NEURONS:
    save_path = os.path.join(save_dir, f"{id}.jpg")

    # Skip if already processed
    if os.path.exists(save_path):
        print(f"Skipping neuron {id} (already exists)")
        continue

    img = activation_maximization(
        model,
        LAYER,
        id,
        image_size=512,
        num_steps=1024
    )

    # Convert to uint8 image
    img_uint8 = (np.clip(img, 0, 1) * 255).astype(np.uint8)

    #Save to drive
    Image.fromarray(img_uint8).save(save_path, quality=95)
    print(f"Saved → {save_path}")

print("Batch processing complete!")
# Out:
# 100%|██████████| 1024/1024 [00:14<00:00, 68.78it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/0.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 77.24it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/1.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 76.33it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/2.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 74.26it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/3.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 76.01it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/4.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 75.56it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/5.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 75.59it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/6.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 75.76it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/7.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 76.12it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/8.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 75.24it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/9.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 74.64it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/10.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 74.94it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/11.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 74.67it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/12.jpg
# 100%|██████████| 1024/1024 [00:13<00:00, 74.03it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/13.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.92it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/14.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.36it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/15.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.39it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/16.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.61it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/17.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.13it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/18.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.55it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/19.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.34it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/20.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.44it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/21.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 70.77it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/22.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 71.27it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/23.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 70.86it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/24.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 70.48it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/25.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 69.87it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/26.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 70.02it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/27.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 69.92it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/28.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 69.88it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/29.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 70.05it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/30.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 70.26it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/31.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 69.47it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/32.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 68.48it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/33.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 68.80it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/34.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 68.27it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/35.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 69.22it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/36.jpg
# 100%|██████████| 1024/1024 [00:14<00:00, 68.41it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/37.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 68.22it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/38.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 67.31it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/39.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 66.66it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/40.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 66.77it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/41.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 66.81it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/42.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 66.75it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/43.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.98it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/44.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.92it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/45.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.94it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/46.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.54it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/47.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.46it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/48.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.61it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/49.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 64.98it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/50.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 64.73it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/51.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 64.58it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/52.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 65.42it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/53.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 64.65it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/54.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 63.97it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/55.jpg
# 100%|██████████| 1024/1024 [00:15<00:00, 64.59it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/56.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 63.70it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/57.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 63.92it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/58.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 62.93it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/59.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 63.34it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/60.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 62.52it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/61.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 62.14it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/62.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 62.78it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/63.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 62.84it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/64.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 63.12it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/65.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 63.05it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/66.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 62.35it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/67.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 61.80it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/68.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.95it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/69.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 61.44it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/70.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.90it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/71.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.24it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/72.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.27it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/73.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.93it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/74.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.65it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/75.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.61it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/76.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.41it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/77.jpg
# 100%|██████████| 1024/1024 [00:17<00:00, 59.63it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/78.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.37it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/79.jpg
# 100%|██████████| 1024/1024 [00:16<00:00, 60.38it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/80.jpg
# 100%|██████████| 1024/1024 [00:17<00:00, 60.15it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b/81.jpg
# 100%|██████████| 1024/1024 [00:17<00:00, 59.92it/s]
# Saved → /content/drive/MyDrive/activation_max_results/mixed3b